# %%
import pandas as pd
from datetime import datetime as dt
from functools import reduce
import calendar
import datetime
import plotly.express as px
import dash_daq as daq
import bar_chart_race as bcr

# %%
# co2_url ='https://raw.githubusercontent.com/gyleodhis/owid_co2_data/master/owid-co2-data.csv'
"""Offline version"""
co2_url = 'assets/owid_c02.csv'
def owidCo2():
    co2_df = pd.read_csv(co2_url, index_col='year')
    co2_df = co2_df[['country','co2','co2_per_capita','trade_co2','coal_co2','cement_co2','oil_co2','gas_co2','gas_co2_per_capita','co2_growth_prct','share_global_co2']]
#     obese_df.columns=['Region','Percentage']
#     co2_df.to_csv('assets/owid_c02.csv')
    return co2_df
owidCo2().head()
# Out:
#           country    co2  co2_per_capita  trade_co2  coal_co2  cement_co2  \
# year
# 1949  Afghanistan  0.015           0.002        NaN     0.015         NaN
# 1950  Afghanistan  0.084           0.011        NaN     0.021         NaN
# 1951  Afghanistan  0.092           0.012        NaN     0.026         NaN
# 1952  Afghanistan  0.092           0.012        NaN     0.032         NaN
# 1953  Afghanistan  0.106           0.013        NaN     0.038         NaN
#
#       oil_co2  gas_co2  gas_co2_per_capita  co2_growth_prct  share_global_co2
# year
# 1949      NaN      NaN                 NaN              NaN               0.0
# 1950    0.063      NaN                 NaN            475.0               0.0
# 1951    0.066      NaN                 NaN              8.7               0.0
# 1952    0.060      NaN                 NaN              0.0               0.0
# 1953    0.068      NaN                 NaN             16.0               0.0
